# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the preprocessed data into a DataFrame
df = pd.read_csv('data_processed.csv')

# Display basic information about the DataFrame
print(df.info())

# Summary statistics
print(df.describe())

# Distribution of sales numbers
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='sales_number', bins=20)
plt.title('Distribution of Sales Numbers')
plt.xlabel('Sales Numbers')
plt.ylabel('Frequency')
plt.show()

# Relationship between fixed item price and sales number
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='fixed_item_price', y='sales_number')
plt.title('Relationship between Fixed Item Price and Sales Number')
plt.xlabel('Fixed Item Price')
plt.ylabel('Sales Numbers')
plt.show()

# Distribution of item prices by shop
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='shop_name', y='fixed_item_price')
plt.title('Distribution of Item Prices by Shop')
plt.xlabel('Shop Name')
plt.ylabel('Fixed Item Price')
plt.xticks(rotation=45)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   item_path         100000 non-null  object
#  1   item_image        100000 non-null  object
#  2   item_name         100000 non-null  object
#  3   fixed_item_price  100000 non-null  int64
#  4   sale_item_price   100000 non-null  int64
#  5   sales_number      100000 non-null  int64
#  6   shop_path         100000 non-null  object
#  7   shop_name         100000 non-null  object
# dtypes: int64(3), object(5)
# memory usage: 6.1+ MB
# None
#        fixed_item_price  sale_item_price   sales_number
# count      1.000000e+05     1.000000e+05  100000.000000
# mean       6.522401e+05     4.770397e+05     246.388630
# std        1.312219e+06     9.671065e+05    2167.960385
# min        1.000000e+03     1.000000e+03       0.000000
# 25%        2.290000e+05     1.590000e+05       1.000000
# 50%        3.800000e+05     2.890000e+05       9.000000
# 75%        6.200000e+05     4.905000e+05      53.000000
# max        1.200000e+08     8.400000e+07  234200.000000
