# %% [markdown]
# ### Fetch the image from the URL and save to npz file
# - **Input**: data.csv (include url images)
# - **Output**: list file npz (include image numpy array)

# %%
import requests
from PIL import Image
import numpy as np
import pandas as pd
import os

# %%
def fix_error_image(image_array):
    print("fix_error_image", image_array.shape)

    if image_array.shape == (320, 320, 4):
        return image_array[:, :, :3]
    else:
        return np.zeros((320, 320, 3), dtype=np.uint8)

# %%
def url_to_numpy(url):
    try:
        # Fetch the image from the URL
        response = requests.get(url, stream=True)
    except:
        print("url failed")
        return np.zeros((320, 320, 3), dtype=np.uint8)

    # Open the image using PIL
    try:
        image = Image.open(response.raw)
    except:
        print("cannot identify image file")
        return np.zeros((320, 320, 3), dtype=np.uint8)

    # Convert the image to a NumPy array
    img_array = np.array(image, dtype=np.uint8)

    # Check shape
    if img_array.shape != (320, 320, 3):
        print("image_url_fail", url)
        img_array = fix_error_image(img_array)

    return img_array

# %%
def save_file(index_file, merged_array):
    np.savez_compressed(f"/content/drive/MyDrive/shopee/images_array_{index_file}.npz", images_array=merged_array)
    print(f"Save file {index_file} successfully!")

# %%
# Read the CSV file into a pandas DataFrame
df = pd.read_csv("/content/drive/MyDrive/shopee/data.csv")

item_image = df['item_image']

print(item_image.shape)
# Out:
# (100000,)

# %%
'''
range_split to split 500 images to 1 file .npz
Start with start_index_file = 0
If fail in index = 10, start_index_file = 10
'''

index_file = 1
range_split = 500
start_index_file = 200

for index, image_url in enumerate(item_image):
    # Init
    if index == 0:
        print("init image_url", image_url)
        merged_array = [url_to_numpy(image_url)]
        continue

    if index/range_split == index_file:
        print("index", index)
        print("index_file", index_file)

        # Increase index file
        print("increase index file")
        index_file += 1

        if index/range_split  < start_index_file - 1:
            continue

        # Save data before
        if index/range_split  >= start_index_file:
            save_file(index_file=index_file-1, merged_array=merged_array)

        # Reset init file
        print()
        print("reset init")
        merged_array = [url_to_numpy(image_url)]
        continue

    # Check condition start index
    if index/range_split  < start_index_file - 1:
        continue

    # Call the function to get the image as a NumPy array
    image_array = url_to_numpy(image_url)

    merged_array = np.concatenate((merged_array, [image_array]), axis=0)

    # Save last data
    if index == len(item_image) - 1:
        print("index", index)
        print("index_file", index_file)
        save_file(index_file=index_file, merged_array=merged_array)
        print("Done get all images!")
# Out:
# init image_url https://down-vn.img.susercontent.com/file/8e4dd848c8609665a8116d56fe44d6ec_tn
# index 500
# index_file 1
# increase index file
# index 1000
# index_file 2
# increase index file
# index 1500
# index_file 3
# increase index file
# index 2000
# index_file 4
# increase index file
# index 2500
# index_file 5
# increase index file
# index 3000
# index_file 6
# increase index file
# index 3500
# index_file 7
# increase index file
# index 4000
# index_file 8
# increase index file
# index 4500
# index_file 9
# increase index file
# index 5000
# index_file 10
# increase index file
# index 5500
# index_file 11
# increase index file
# index 6000
# index_file 12
# increase index file
# index 6500
# index_file 13
# increase index file
# index 7000
# index_file 14
# increase index file
# index 7500
# index_file 15
# increase index file
# index 8000
# index_file 16
# increase index file
# index 8500
# index_file 17
# increase index file
# index 9000
# index_file 18
# increase index file
# index 9500
# index_file 19
# increase index file
# index 10000
# index_file 20
# increase index file
# index 10500
# index_file 21
# increase index file
# index 11000
# index_file 22
# increase index file
# index 11500
# index_file 23
# increase index file
# index 12000
# index_file 24
# increase index file
# index 12500
# index_file 25
# increase index file
# index 13000
# index_file 26
# increase index file
# index 13500
# index_file 27
# increase index file
# index 14000
# index_file 28
# increase index file
# index 14500
# index_file 29
# increase index file
# index 15000
# index_file 30
# increase index file
# index 15500
# index_file 31
# increase index file
# index 16000
# index_file 32
# increase index file
# index 16500
# index_file 33
# increase index file
# index 17000
# index_file 34
# increase index file
# index 17500
# index_file 35
# increase index file
# index 18000
# index_file 36
# increase index file
# index 18500
# index_file 37
# increase index file
# index 19000
# index_file 38
# increase index file
# index 19500
# index_file 39
# increase index file
# index 20000
# index_file 40
# increase index file
# index 20500
# index_file 41
# increase index file
# index 21000
# index_file 42
# increase index file
# index 21500
# index_file 43
# increase index file
# index 22000
# index_file 44
# increase index file
# index 22500
# index_file 45
# increase index file
# index 23000
# index_file 46
# increase index file
# index 23500
# index_file 47
# increase index file
# index 24000
# index_file 48
# increase index file
# index 24500
# index_file 49
# increase index file
# index 25000
# index_file 50
# increase index file
# index 25500
# index_file 51
# increase index file
# index 26000
# index_file 52
# increase index file
# index 26500
# index_file 53
# increase index file
# index 27000
# index_file 54
# increase index file
# index 27500
# index_file 55
# increase index file
# index 28000
# index_file 56
# increase index file
# index 28500
# index_file 57
# increase index file
# index 29000
# index_file 58
# increase index file
# index 29500
# index_file 59
# increase index file
# index 30000
# index_file 60
# increase index file
# index 30500
# index_file 61
# increase index file
# index 31000
# index_file 62
# increase index file
# index 31500
# index_file 63
# increase index file
# index 32000
# index_file 64
# increase index file
# index 32500
# index_file 65
# increase index file
# index 33000
# index_file 66
# increase index file
# index 33500
# index_file 67
# increase index file
# index 34000
# index_file 68
# increase index file
# index 34500
# index_file 69
# increase index file
# index 35000
# index_file 70
# increase index file
# index 35500
# index_file 71
# increase index file
# index 36000
# index_file 72
# increase index file
# index 36500
# index_file 73
# increase index file
# index 37000
# index_file 74
# increase index file
# index 37500
# index_file 75
# increase index file
# index 38000
# index_file 76
# increase index file
# index 38500
# index_file 77
# increase index file
# index 39000
# index_file 78
# increase index file
# index 39500
# index_file 79
# increase index file
# index 40000
# index_file 80
# increase index file
# index 40500
# index_file 81
# increase index file
# index 41000
# index_file 82
# increase index file
# index 41500
# index_file 83
# increase index file
# index 42000
# index_file 84
# increase index file
# index 42500
# index_file 85
# increase index file
# index 43000
# index_file 86
# increase index file
# index 43500
# index_file 87
# increase index file
# index 44000
# index_file 88
# increase index file
# index 44500
# index_file 89
# increase index file
# index 45000
# index_file 90
# increase index file
# index 45500
# index_file 91
# increase index file
# index 46000
# index_file 92
# increase index file
# index 46500
# index_file 93
# increase index file
# index 47000
# index_file 94
# increase index file
# index 47500
# index_file 95
# increase index file
# index 48000
# index_file 96
# increase index file
# index 48500
# index_file 97
# increase index file
# index 49000
# index_file 98
# increase index file
# index 49500
# index_file 99
# increase index file
# index 50000
# index_file 100
# increase index file
# index 50500
# index_file 101
# increase index file
# index 51000
# index_file 102
# increase index file
# index 51500
# index_file 103
# increase index file
# index 52000
# index_file 104
# increase index file
# index 52500
# index_file 105
# increase index file
# index 53000
# index_file 106
# increase index file
# index 53500
# index_file 107
# increase index file
# index 54000
# index_file 108
# increase index file
# index 54500
# index_file 109
# increase index file
# index 55000
# index_file 110
# increase index file
# index 55500
# index_file 111
# increase index file
# index 56000
# index_file 112
# increase index file
# index 56500
# index_file 113
# increase index file
# index 57000
# index_file 114
# increase index file
# index 57500
# index_file 115
# increase index file
# index 58000
# index_file 116
# increase index file
# index 58500
# index_file 117
# increase index file
# index 59000
# index_file 118
# increase index file
# index 59500
# index_file 119
# increase index file
# index 60000
# index_file 120
# increase index file
# index 60500
# index_file 121
# increase index file
# index 61000
# index_file 122
# increase index file
# index 61500
# index_file 123
# increase index file
# index 62000
# index_file 124
# increase index file
# index 62500
# index_file 125
# increase index file
# index 63000
# index_file 126
# increase index file
# index 63500
# index_file 127
# increase index file
# index 64000
# index_file 128
# increase index file
# index 64500
# index_file 129
# increase index file
# index 65000
# index_file 130
# increase index file
# index 65500
# index_file 131
# increase index file
# index 66000
# index_file 132
# increase index file
# index 66500
# index_file 133
# increase index file
# index 67000
# index_file 134
# increase index file
# index 67500
# index_file 135
# increase index file
# index 68000
# index_file 136
# increase index file
# index 68500
# index_file 137
# increase index file
# index 69000
# index_file 138
# increase index file
# index 69500
# index_file 139
# increase index file
# index 70000
# index_file 140
# increase index file
# index 70500
# index_file 141
# increase index file
# index 71000
# index_file 142
# increase index file
# index 71500
# index_file 143
# increase index file
# index 72000
# index_file 144
# increase index file
# index 72500
# index_file 145
# increase index file
# index 73000
# index_file 146
# increase index file
# index 73500
# index_file 147
# increase index file
# index 74000
# index_file 148
# increase index file
# index 74500
# index_file 149
# increase index file
# index 75000
# index_file 150
# increase index file
# index 75500
# index_file 151
# increase index file
# index 76000
# index_file 152
# increase index file
# index 76500
# index_file 153
# increase index file
# index 77000
# index_file 154
# increase index file
# index 77500
# index_file 155
# increase index file
# index 78000
# index_file 156
# increase index file
# index 78500
# index_file 157
# increase index file
# index 79000
# index_file 158
# increase index file
# index 79500
# index_file 159
# increase index file
# index 80000
# index_file 160
# increase index file
# index 80500
# index_file 161
# increase index file
# index 81000
# index_file 162
# increase index file
# index 81500
# index_file 163
# increase index file
# index 82000
# index_file 164
# increase index file
# index 82500
# index_file 165
# increase index file
# index 83000
# index_file 166
# increase index file
# index 83500
# index_file 167
# increase index file
# index 84000
# index_file 168
# increase index file
# index 84500
# index_file 169
# increase index file
# index 85000
# index_file 170
# increase index file
# index 85500
# index_file 171
# increase index file
# index 86000
# index_file 172
# increase index file
# index 86500
# index_file 173
# increase index file
# index 87000
# index_file 174
# increase index file
# index 87500
# index_file 175
# increase index file
# index 88000
# index_file 176
# increase index file
# index 88500
# index_file 177
# increase index file
# index 89000
# index_file 178
# increase index file
# index 89500
# index_file 179
# increase index file
# index 90000
# index_file 180
# increase index file
# index 90500
# index_file 181
# increase index file
# index 91000
# index_file 182
# increase index file
# index 91500
# index_file 183
# increase index file
# index 92000
# index_file 184
# increase index file
# index 92500
# index_file 185
# increase index file
# index 93000
# index_file 186
# increase index file
# index 93500
# index_file 187
# increase index file
# index 94000
# index_file 188
# increase index file
# index 94500
# index_file 189
# increase index file
# index 95000
# index_file 190
# increase index file
# index 95500
# index_file 191
# increase index file
# index 96000
# index_file 192
# increase index file
# index 96500
# index_file 193
# increase index file
# index 97000
# index_file 194
# increase index file
# index 97500
# index_file 195
# increase index file
# index 98000
# index_file 196
# increase index file
# index 98500
# index_file 197
# increase index file
# index 99000
# index_file 198
# increase index file
# index 99500
# index_file 199
# increase index file
#
# reset init
# index 99999
# index_file 200
# Save file 200 successfully!
# Done get all images!

# %% [markdown]
# Check file

# %%
import numpy as np
import matplotlib.pyplot as plt

file_path = "/content/drive/MyDrive/shopee/"

data = np.load(file_path + "images_array_200.npz", allow_pickle=True)

imgs_feature = data["images_array"]

print(imgs_feature.shape)

print(type(imgs_feature[0][0][0][0]))

plt.figure(figsize=(4,4))
plt.imshow(imgs_feature[0])
# Out:
# (500, 320, 320, 3)
# <class 'numpy.uint8'>

# %% [markdown]
# ### Load image array and inference with model
# - **Input**: list file npz (include image numpy array)
# - **Output**: features file npz (include feature inference from model)

# %%
import os
import numpy as np
import torch
import torchvision.models as models

file_path = "/content/drive/MyDrive/shopee/"
list_file_array = [name for name in os.listdir(file_path) if name.endswith((".npz"))]

print("Total file .npz:", len(list_file_array))
print("Sample file:", list_file_array[0])

if torch.cuda.is_available():
    print("Device: cuda")
else:
    print("Device: cpu")
# Out:
# Total file .npz: 200
# Sample file: images_array_1.npz
# Device: cuda

# %%
# Create numpy array save features
image_features = None

for index_file in range(len(list_file_array)):
    file_name = f"images_array_{index_file+1}.npz"

    print("file_name:", file_name)

    # Load from npz file
    data = np.load(file_path + file_name, allow_pickle=True)

    # Get image array
    input_data = data["images_array"]

    # Convert to shape (B, C, H, W)
    input_data = input_data.transpose((0, 3, 1, 2))

    # Convert to a PyTorch tensor
    input_data = input_data.astype(np.float32) / 255.0
    input_data = torch.tensor(input_data, dtype=torch.float32)

    # Load the pre-trained model
    efficientnet_b3 = models.efficientnet_b3(weights='IMAGENET1K_V1')

    # Set the model to evaluation mode
    efficientnet_b3.eval()

    # Use a GPU (if available) for inference
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    efficientnet_b3 = efficientnet_b3.to(device)
    input_data = input_data.to(device)

    batch_size = 125
    num_samples = input_data.shape[0]
    num_batches = (num_samples + batch_size - 1) // batch_size

    # Log info
    if index_file == 0:
        print("batch_size", batch_size)
        print("num_samples", num_samples)
        print("num_batches", num_batches)

    # Inference loop
    with torch.no_grad():
        for i in range(num_batches):
            # Spit to batch
            start_idx = i * batch_size
            end_idx = min((i + 1) * batch_size, num_samples)
            batch = input_data[start_idx:end_idx]

            # Forward pass through the model
            outputs = efficientnet_b3(batch)

            # Convert to numpy array
            outputs = outputs.detach().cpu().numpy()

            # Save features
            if index_file == 0 and i == 0:
                image_features = outputs
            else:
                image_features = np.concatenate((image_features, outputs), axis=0)

            print(image_features.shape)

image_features.shape
np.savez_compressed(f"{file_path}image_features/image_features.npz", image_features=image_features)
print(f"Save file image_features successfully!")
# Out:
# file_name: images_array_1.npz
# batch_size 125
# num_samples 500
# num_batches 4
# (125, 1000)
# (250, 1000)
# (375, 1000)
# (500, 1000)
# file_name: images_array_2.npz
# (625, 1000)
# (750, 1000)
# (875, 1000)
# (1000, 1000)
# file_name: images_array_3.npz
# (1125, 1000)
# (1250, 1000)
# (1375, 1000)
# (1500, 1000)
# file_name: images_array_4.npz
# (1625, 1000)
# (1750, 1000)
# (1875, 1000)
# (2000, 1000)
# file_name: images_array_5.npz
# (2125, 1000)
# (2250, 1000)
# (2375, 1000)
# (2500, 1000)
# file_name: images_array_6.npz
# (2625, 1000)
# (2750, 1000)
# (2875, 1000)
# (3000, 1000)
# file_name: images_array_7.npz
# (3125, 1000)
# (3250, 1000)
# (3375, 1000)
# (3500, 1000)
# file_name: images_array_8.npz
# (3625, 1000)
# (3750, 1000)
# (3875, 1000)
# (4000, 1000)
# file_name: images_array_9.npz
# (4125, 1000)
# (4250, 1000)
# (4375, 1000)
# (4500, 1000)
# file_name: images_array_10.npz
# (4625, 1000)
# (4750, 1000)
# (4875, 1000)
# (5000, 1000)
# file_name: images_array_11.npz
# (5125, 1000)
# (5250, 1000)
# (5375, 1000)
# (5500, 1000)
# file_name: images_array_12.npz
# (5625, 1000)
# (5750, 1000)
# (5875, 1000)
# (6000, 1000)
# file_name: images_array_13.npz
# (6125, 1000)
# (6250, 1000)
# (6375, 1000)
# (6500, 1000)
# file_name: images_array_14.npz
# (6625, 1000)
# (6750, 1000)
# (6875, 1000)
# (7000, 1000)
# file_name: images_array_15.npz
# (7125, 1000)
# (7250, 1000)
# (7375, 1000)
# (7500, 1000)
# file_name: images_array_16.npz
# (7625, 1000)
# (7750, 1000)
# (7875, 1000)
# (8000, 1000)
# file_name: images_array_17.npz
# (8125, 1000)
# (8250, 1000)
# (8375, 1000)
# (8500, 1000)
# file_name: images_array_18.npz
# (8625, 1000)
# (8750, 1000)
# (8875, 1000)
# (9000, 1000)
# file_name: images_array_19.npz
# (9125, 1000)
# (9250, 1000)
# (9375, 1000)
# (9500, 1000)
# file_name: images_array_20.npz
# (9625, 1000)
# (9750, 1000)
# (9875, 1000)
# (10000, 1000)
# file_name: images_array_21.npz
# (10125, 1000)
# (10250, 1000)
# (10375, 1000)
# (10500, 1000)
# file_name: images_array_22.npz
# (10625, 1000)
# (10750, 1000)
# (10875, 1000)
# (11000, 1000)
# file_name: images_array_23.npz
# (11125, 1000)
# (11250, 1000)
# (11375, 1000)
# (11500, 1000)
# file_name: images_array_24.npz
# (11625, 1000)
# (11750, 1000)
# (11875, 1000)
# (12000, 1000)
# file_name: images_array_25.npz
# (12125, 1000)
# (12250, 1000)
# (12375, 1000)
# (12500, 1000)
# file_name: images_array_26.npz
# (12625, 1000)
# (12750, 1000)
# (12875, 1000)
# (13000, 1000)
# file_name: images_array_27.npz
# (13125, 1000)
# (13250, 1000)
# (13375, 1000)
# (13500, 1000)
# file_name: images_array_28.npz
# (13625, 1000)
# (13750, 1000)
# (13875, 1000)
# (14000, 1000)
# file_name: images_array_29.npz
# (14125, 1000)
# (14250, 1000)
# (14375, 1000)
# (14500, 1000)
# file_name: images_array_30.npz
# (14625, 1000)
# (14750, 1000)
# (14875, 1000)
# (15000, 1000)
# file_name: images_array_31.npz
# (15125, 1000)
# (15250, 1000)
# (15375, 1000)
# (15500, 1000)
# file_name: images_array_32.npz
# (15625, 1000)
# (15750, 1000)
# (15875, 1000)
# (16000, 1000)
# file_name: images_array_33.npz
# (16125, 1000)
# (16250, 1000)
# (16375, 1000)
# (16500, 1000)
# file_name: images_array_34.npz
# (16625, 1000)
# (16750, 1000)
# (16875, 1000)
# (17000, 1000)
# file_name: images_array_35.npz
# (17125, 1000)
# (17250, 1000)
# (17375, 1000)
# (17500, 1000)
# file_name: images_array_36.npz
# (17625, 1000)
# (17750, 1000)
# (17875, 1000)
# (18000, 1000)
# file_name: images_array_37.npz
# (18125, 1000)
# (18250, 1000)
# (18375, 1000)
# (18500, 1000)
# file_name: images_array_38.npz
# (18625, 1000)
# (18750, 1000)
# (18875, 1000)
# (19000, 1000)
# file_name: images_array_39.npz
# (19125, 1000)
# (19250, 1000)
# (19375, 1000)
# (19500, 1000)
# file_name: images_array_40.npz
# (19625, 1000)
# (19750, 1000)
# (19875, 1000)
# (20000, 1000)
# file_name: images_array_41.npz
# (20125, 1000)
# (20250, 1000)
# (20375, 1000)
# (20500, 1000)
# file_name: images_array_42.npz
# (20625, 1000)
# (20750, 1000)
# (20875, 1000)
# (21000, 1000)
# file_name: images_array_43.npz
# (21125, 1000)
# (21250, 1000)
# (21375, 1000)
# (21500, 1000)
# file_name: images_array_44.npz
# (21625, 1000)
# (21750, 1000)
# (21875, 1000)
# (22000, 1000)
# file_name: images_array_45.npz
# (22125, 1000)
# (22250, 1000)
# (22375, 1000)
# (22500, 1000)
# file_name: images_array_46.npz
# (22625, 1000)
# (22750, 1000)
# (22875, 1000)
# (23000, 1000)
# file_name: images_array_47.npz
# (23125, 1000)
# (23250, 1000)
# (23375, 1000)
# (23500, 1000)
# file_name: images_array_48.npz
# (23625, 1000)
# (23750, 1000)
# (23875, 1000)
# (24000, 1000)
# file_name: images_array_49.npz
# (24125, 1000)
# (24250, 1000)
# (24375, 1000)
# (24500, 1000)
# file_name: images_array_50.npz
# (24625, 1000)
# (24750, 1000)
# (24875, 1000)
# (25000, 1000)
# file_name: images_array_51.npz
# (25125, 1000)
# (25250, 1000)
# (25375, 1000)
# (25500, 1000)
# file_name: images_array_52.npz
# (25625, 1000)
# (25750, 1000)
# (25875, 1000)
# (26000, 1000)
# file_name: images_array_53.npz
# (26125, 1000)
# (26250, 1000)
# (26375, 1000)
# (26500, 1000)
# file_name: images_array_54.npz
# (26625, 1000)
# (26750, 1000)
# (26875, 1000)
# (27000, 1000)
# file_name: images_array_55.npz
# (27125, 1000)
# (27250, 1000)
# (27375, 1000)
# (27500, 1000)
# file_name: images_array_56.npz
# (27625, 1000)
# (27750, 1000)
# (27875, 1000)
# (28000, 1000)
# file_name: images_array_57.npz
# (28125, 1000)
# (28250, 1000)
# (28375, 1000)
# (28500, 1000)
# file_name: images_array_58.npz
# (28625, 1000)
# (28750, 1000)
# (28875, 1000)
# (29000, 1000)
# file_name: images_array_59.npz
# (29125, 1000)
# (29250, 1000)
# (29375, 1000)
# (29500, 1000)
# file_name: images_array_60.npz
# (29625, 1000)
# (29750, 1000)
# (29875, 1000)
# (30000, 1000)
# file_name: images_array_61.npz
# (30125, 1000)
# (30250, 1000)
# (30375, 1000)
# (30500, 1000)
# file_name: images_array_62.npz
# (30625, 1000)
# (30750, 1000)
# (30875, 1000)
# (31000, 1000)
# file_name: images_array_63.npz
# (31125, 1000)
# (31250, 1000)
# (31375, 1000)
# (31500, 1000)
# file_name: images_array_64.npz
# (31625, 1000)
# (31750, 1000)
# (31875, 1000)
# (32000, 1000)
# file_name: images_array_65.npz
# (32125, 1000)
# (32250, 1000)
# (32375, 1000)
# (32500, 1000)
# file_name: images_array_66.npz
# (32625, 1000)
# (32750, 1000)
# (32875, 1000)
# (33000, 1000)
# file_name: images_array_67.npz
# (33125, 1000)
# (33250, 1000)
# (33375, 1000)
# (33500, 1000)
# file_name: images_array_68.npz
# (33625, 1000)
# (33750, 1000)
# (33875, 1000)
# (34000, 1000)
# file_name: images_array_69.npz
# (34125, 1000)
# (34250, 1000)
# (34375, 1000)
# (34500, 1000)
# file_name: images_array_70.npz
# (34625, 1000)
# (34750, 1000)
# (34875, 1000)
# (35000, 1000)
# file_name: images_array_71.npz
# (35125, 1000)
# (35250, 1000)
# (35375, 1000)
# (35500, 1000)
# file_name: images_array_72.npz
# (35625, 1000)
# (35750, 1000)
# (35875, 1000)
# (36000, 1000)
# file_name: images_array_73.npz
# (36125, 1000)
# (36250, 1000)
# (36375, 1000)
# (36500, 1000)
# file_name: images_array_74.npz
# (36625, 1000)
# (36750, 1000)
# (36875, 1000)
# (37000, 1000)
# file_name: images_array_75.npz
# (37125, 1000)
# (37250, 1000)
# (37375, 1000)
# (37500, 1000)
# file_name: images_array_76.npz
# (37625, 1000)
# (37750, 1000)
# (37875, 1000)
# (38000, 1000)
# file_name: images_array_77.npz
# (38125, 1000)
# (38250, 1000)
# (38375, 1000)
# (38500, 1000)
# file_name: images_array_78.npz
# (38625, 1000)
# (38750, 1000)
# (38875, 1000)
# (39000, 1000)
# file_name: images_array_79.npz
# (39125, 1000)
# (39250, 1000)
# (39375, 1000)
# (39500, 1000)
# file_name: images_array_80.npz
# (39625, 1000)
# (39750, 1000)
# (39875, 1000)
# (40000, 1000)
# file_name: images_array_81.npz
# (40125, 1000)
# (40250, 1000)
# (40375, 1000)
# (40500, 1000)
# file_name: images_array_82.npz
# (40625, 1000)
# (40750, 1000)
# (40875, 1000)
# (41000, 1000)
# file_name: images_array_83.npz
# (41125, 1000)
# (41250, 1000)
# (41375, 1000)
# (41500, 1000)
# file_name: images_array_84.npz
# (41625, 1000)
# (41750, 1000)
# (41875, 1000)
# (42000, 1000)
# file_name: images_array_85.npz
# (42125, 1000)
# (42250, 1000)
# (42375, 1000)
# (42500, 1000)
# file_name: images_array_86.npz
# (42625, 1000)
# (42750, 1000)
# (42875, 1000)
# (43000, 1000)
# file_name: images_array_87.npz
# (43125, 1000)
# (43250, 1000)
# (43375, 1000)
# (43500, 1000)
# file_name: images_array_88.npz
# (43625, 1000)
# (43750, 1000)
# (43875, 1000)
# (44000, 1000)
# file_name: images_array_89.npz
# (44125, 1000)
# (44250, 1000)
# (44375, 1000)
# (44500, 1000)
# file_name: images_array_90.npz
# (44625, 1000)
# (44750, 1000)
# (44875, 1000)
# (45000, 1000)
# file_name: images_array_91.npz
# (45125, 1000)
# (45250, 1000)
# (45375, 1000)
# (45500, 1000)
# file_name: images_array_92.npz
# (45625, 1000)
# (45750, 1000)
# (45875, 1000)
# (46000, 1000)
# file_name: images_array_93.npz
# (46125, 1000)
# (46250, 1000)
# (46375, 1000)
# (46500, 1000)
# file_name: images_array_94.npz
# (46625, 1000)
# (46750, 1000)
# (46875, 1000)
# (47000, 1000)
# file_name: images_array_95.npz
# (47125, 1000)
# (47250, 1000)
# (47375, 1000)
# (47500, 1000)
# file_name: images_array_96.npz
# (47625, 1000)
# (47750, 1000)
# (47875, 1000)
# (48000, 1000)
# file_name: images_array_97.npz
# (48125, 1000)
# (48250, 1000)
# (48375, 1000)
# (48500, 1000)
# file_name: images_array_98.npz
# (48625, 1000)
# (48750, 1000)
# (48875, 1000)
# (49000, 1000)
# file_name: images_array_99.npz
# (49125, 1000)
# (49250, 1000)
# (49375, 1000)
# (49500, 1000)
# file_name: images_array_100.npz
# (49625, 1000)
# (49750, 1000)
# (49875, 1000)
# (50000, 1000)
# file_name: images_array_101.npz
# (50125, 1000)
# (50250, 1000)
# (50375, 1000)
# (50500, 1000)
# file_name: images_array_102.npz
# (50625, 1000)
# (50750, 1000)
# (50875, 1000)
# (51000, 1000)
# file_name: images_array_103.npz
# (51125, 1000)
# (51250, 1000)
# (51375, 1000)
# (51500, 1000)
# file_name: images_array_104.npz
# (51625, 1000)
# (51750, 1000)
# (51875, 1000)
# (52000, 1000)
# file_name: images_array_105.npz
# (52125, 1000)
# (52250, 1000)
# (52375, 1000)
# (52500, 1000)
# file_name: images_array_106.npz
# (52625, 1000)
# (52750, 1000)
# (52875, 1000)
# (53000, 1000)
# file_name: images_array_107.npz
# (53125, 1000)
# (53250, 1000)
# (53375, 1000)
# (53500, 1000)
# file_name: images_array_108.npz
# (53625, 1000)
# (53750, 1000)
# (53875, 1000)
# (54000, 1000)
# file_name: images_array_109.npz
# (54125, 1000)
# (54250, 1000)
# (54375, 1000)
# (54500, 1000)
# file_name: images_array_110.npz
# (54625, 1000)
# (54750, 1000)
# (54875, 1000)
# (55000, 1000)
# file_name: images_array_111.npz
# (55125, 1000)
# (55250, 1000)
# (55375, 1000)
# (55500, 1000)
# file_name: images_array_112.npz
# (55625, 1000)
# (55750, 1000)
# (55875, 1000)
# (56000, 1000)
# file_name: images_array_113.npz
# (56125, 1000)
# (56250, 1000)
# (56375, 1000)
# (56500, 1000)
# file_name: images_array_114.npz
# (56625, 1000)
# (56750, 1000)
# (56875, 1000)
# (57000, 1000)
# file_name: images_array_115.npz
# (57125, 1000)
# (57250, 1000)
# (57375, 1000)
# (57500, 1000)
# file_name: images_array_116.npz
# (57625, 1000)
# (57750, 1000)
# (57875, 1000)
# (58000, 1000)
# file_name: images_array_117.npz
# (58125, 1000)
# (58250, 1000)
# (58375, 1000)
# (58500, 1000)
# file_name: images_array_118.npz
# (58625, 1000)
# (58750, 1000)
# (58875, 1000)
# (59000, 1000)
# file_name: images_array_119.npz
# (59125, 1000)
# (59250, 1000)
# (59375, 1000)
# (59500, 1000)
# file_name: images_array_120.npz
# (59625, 1000)
# (59750, 1000)
# (59875, 1000)
# (60000, 1000)
# file_name: images_array_121.npz
# (60125, 1000)
# (60250, 1000)
# (60375, 1000)
# (60500, 1000)
# file_name: images_array_122.npz
# (60625, 1000)
# (60750, 1000)
# (60875, 1000)
# (61000, 1000)
# file_name: images_array_123.npz
# (61125, 1000)
# (61250, 1000)
# (61375, 1000)
# (61500, 1000)
# file_name: images_array_124.npz
# (61625, 1000)
# (61750, 1000)
# (61875, 1000)
# (62000, 1000)
# file_name: images_array_125.npz
# (62125, 1000)
# (62250, 1000)
# (62375, 1000)
# (62500, 1000)
# file_name: images_array_126.npz
# (62625, 1000)
# (62750, 1000)
# (62875, 1000)
# (63000, 1000)
# file_name: images_array_127.npz
# (63125, 1000)
# (63250, 1000)
# (63375, 1000)
# (63500, 1000)
# file_name: images_array_128.npz
# (63625, 1000)
# (63750, 1000)
# (63875, 1000)
# (64000, 1000)
# file_name: images_array_129.npz
# (64125, 1000)
# (64250, 1000)
# (64375, 1000)
# (64500, 1000)
# file_name: images_array_130.npz
# (64625, 1000)
# (64750, 1000)
# (64875, 1000)
# (65000, 1000)
# file_name: images_array_131.npz
# (65125, 1000)
# (65250, 1000)
# (65375, 1000)
# (65500, 1000)
# file_name: images_array_132.npz
# (65625, 1000)
# (65750, 1000)
# (65875, 1000)
# (66000, 1000)
# file_name: images_array_133.npz
# (66125, 1000)
# (66250, 1000)
# (66375, 1000)
# (66500, 1000)
# file_name: images_array_134.npz
# (66625, 1000)
# (66750, 1000)
# (66875, 1000)
# (67000, 1000)
# file_name: images_array_135.npz
# (67125, 1000)
# (67250, 1000)
# (67375, 1000)
# (67500, 1000)
# file_name: images_array_136.npz
# (67625, 1000)
# (67750, 1000)
# (67875, 1000)
# (68000, 1000)
# file_name: images_array_137.npz
# (68125, 1000)
# (68250, 1000)
# (68375, 1000)
# (68500, 1000)
# file_name: images_array_138.npz
# (68625, 1000)
# (68750, 1000)
# (68875, 1000)
# (69000, 1000)
# file_name: images_array_139.npz
# (69125, 1000)
# (69250, 1000)
# (69375, 1000)
# (69500, 1000)
# file_name: images_array_140.npz
# (69625, 1000)
# (69750, 1000)
# (69875, 1000)
# (70000, 1000)
# file_name: images_array_141.npz
# (70125, 1000)
# (70250, 1000)
# (70375, 1000)
# (70500, 1000)
# file_name: images_array_142.npz
# (70625, 1000)
# (70750, 1000)
# (70875, 1000)
# (71000, 1000)
# file_name: images_array_143.npz
# (71125, 1000)
# (71250, 1000)
# (71375, 1000)
# (71500, 1000)
# file_name: images_array_144.npz
# (71625, 1000)
# (71750, 1000)
# (71875, 1000)
# (72000, 1000)
# file_name: images_array_145.npz
# (72125, 1000)
# (72250, 1000)
# (72375, 1000)
# (72500, 1000)
# file_name: images_array_146.npz
# (72625, 1000)
# (72750, 1000)
# (72875, 1000)
# (73000, 1000)
# file_name: images_array_147.npz
# (73125, 1000)
# (73250, 1000)
# (73375, 1000)
# (73500, 1000)
# file_name: images_array_148.npz
# (73625, 1000)
# (73750, 1000)
# (73875, 1000)
# (74000, 1000)
# file_name: images_array_149.npz
# (74125, 1000)
# (74250, 1000)
# (74375, 1000)
# (74500, 1000)
# file_name: images_array_150.npz
# (74625, 1000)
# (74750, 1000)
# (74875, 1000)
# (75000, 1000)
# file_name: images_array_151.npz
# (75125, 1000)
# (75250, 1000)
# (75375, 1000)
# (75500, 1000)
# file_name: images_array_152.npz
# (75625, 1000)
# (75750, 1000)
# (75875, 1000)
# (76000, 1000)
# file_name: images_array_153.npz
# (76125, 1000)
# (76250, 1000)
# (76375, 1000)
# (76500, 1000)
# file_name: images_array_154.npz
# (76625, 1000)
# (76750, 1000)
# (76875, 1000)
# (77000, 1000)
# file_name: images_array_155.npz
# (77125, 1000)
# (77250, 1000)
# (77375, 1000)
# (77500, 1000)
# file_name: images_array_156.npz
# (77625, 1000)
# (77750, 1000)
# (77875, 1000)
# (78000, 1000)
# file_name: images_array_157.npz
# (78125, 1000)
# (78250, 1000)
# (78375, 1000)
# (78500, 1000)
# file_name: images_array_158.npz
# (78625, 1000)
# (78750, 1000)
# (78875, 1000)
# (79000, 1000)
# file_name: images_array_159.npz
# (79125, 1000)
# (79250, 1000)
# (79375, 1000)
# (79500, 1000)
# file_name: images_array_160.npz
# (79625, 1000)
# (79750, 1000)
# (79875, 1000)
# (80000, 1000)
# file_name: images_array_161.npz
# (80125, 1000)
# (80250, 1000)
# (80375, 1000)
# (80500, 1000)
# file_name: images_array_162.npz
# (80625, 1000)
# (80750, 1000)
# (80875, 1000)
# (81000, 1000)
# file_name: images_array_163.npz
# (81125, 1000)
# (81250, 1000)
# (81375, 1000)
# (81500, 1000)
# file_name: images_array_164.npz
# (81625, 1000)
# (81750, 1000)
# (81875, 1000)
# (82000, 1000)
# file_name: images_array_165.npz
# (82125, 1000)
# (82250, 1000)
# (82375, 1000)
# (82500, 1000)
# file_name: images_array_166.npz
# (82625, 1000)
# (82750, 1000)
# (82875, 1000)
# (83000, 1000)
# file_name: images_array_167.npz
# (83125, 1000)
# (83250, 1000)
# (83375, 1000)
# (83500, 1000)
# file_name: images_array_168.npz
# (83625, 1000)
# (83750, 1000)
# (83875, 1000)
# (84000, 1000)
# file_name: images_array_169.npz
# (84125, 1000)
# (84250, 1000)
# (84375, 1000)
# (84500, 1000)
# file_name: images_array_170.npz
# (84625, 1000)
# (84750, 1000)
# (84875, 1000)
# (85000, 1000)
# file_name: images_array_171.npz
# (85125, 1000)
# (85250, 1000)
# (85375, 1000)
# (85500, 1000)
# file_name: images_array_172.npz
# (85625, 1000)
# (85750, 1000)
# (85875, 1000)
# (86000, 1000)
# file_name: images_array_173.npz
# (86125, 1000)
# (86250, 1000)
# (86375, 1000)
# (86500, 1000)
# file_name: images_array_174.npz
# (86625, 1000)
# (86750, 1000)
# (86875, 1000)
# (87000, 1000)
# file_name: images_array_175.npz
# (87125, 1000)
# (87250, 1000)
# (87375, 1000)
# (87500, 1000)
# file_name: images_array_176.npz
# (87625, 1000)
# (87750, 1000)
# (87875, 1000)
# (88000, 1000)
# file_name: images_array_177.npz
# (88125, 1000)
# (88250, 1000)
# (88375, 1000)
# (88500, 1000)
# file_name: images_array_178.npz
# (88625, 1000)
# (88750, 1000)
# (88875, 1000)
# (89000, 1000)
# file_name: images_array_179.npz
# (89125, 1000)
# (89250, 1000)
# (89375, 1000)
# (89500, 1000)
# file_name: images_array_180.npz
# (89625, 1000)
# (89750, 1000)
# (89875, 1000)
# (90000, 1000)
# file_name: images_array_181.npz
# (90125, 1000)
# (90250, 1000)
# (90375, 1000)
# (90500, 1000)
# file_name: images_array_182.npz
# (90625, 1000)
# (90750, 1000)
# (90875, 1000)
# (91000, 1000)
# file_name: images_array_183.npz
# (91125, 1000)
# (91250, 1000)
# (91375, 1000)
# (91500, 1000)
# file_name: images_array_184.npz
# (91625, 1000)
# (91750, 1000)
# (91875, 1000)
# (92000, 1000)
# file_name: images_array_185.npz
# (92125, 1000)
# (92250, 1000)
# (92375, 1000)
# (92500, 1000)
# file_name: images_array_186.npz
# (92625, 1000)
# (92750, 1000)
# (92875, 1000)
# (93000, 1000)
# file_name: images_array_187.npz
# (93125, 1000)
# (93250, 1000)
# (93375, 1000)
# (93500, 1000)
# file_name: images_array_188.npz
# (93625, 1000)
# (93750, 1000)
# (93875, 1000)
# (94000, 1000)
# file_name: images_array_189.npz
# (94125, 1000)
# (94250, 1000)
# (94375, 1000)
# (94500, 1000)
# file_name: images_array_190.npz
# (94625, 1000)
# (94750, 1000)
# (94875, 1000)
# (95000, 1000)
# file_name: images_array_191.npz
# (95125, 1000)
# (95250, 1000)
# (95375, 1000)
# (95500, 1000)
# file_name: images_array_192.npz
# (95625, 1000)
# (95750, 1000)
# (95875, 1000)
# (96000, 1000)
# file_name: images_array_193.npz
# (96125, 1000)
# (96250, 1000)
# (96375, 1000)
# (96500, 1000)
# file_name: images_array_194.npz
# (96625, 1000)
# (96750, 1000)
# (96875, 1000)
# (97000, 1000)
# file_name: images_array_195.npz
# (97125, 1000)
# (97250, 1000)
# (97375, 1000)
# (97500, 1000)
# file_name: images_array_196.npz
# (97625, 1000)
# (97750, 1000)
# (97875, 1000)
# (98000, 1000)
# file_name: images_array_197.npz
# (98125, 1000)
# (98250, 1000)
# (98375, 1000)
# (98500, 1000)
# file_name: images_array_198.npz
# (98625, 1000)
# (98750, 1000)
# (98875, 1000)
# (99000, 1000)
# file_name: images_array_199.npz
# (99125, 1000)
# (99250, 1000)
# (99375, 1000)
# (99500, 1000)
# file_name: images_array_200.npz
# (99625, 1000)
# (99750, 1000)
# (99875, 1000)
# (100000, 1000)
# Save file image_features successfully!

# %% [markdown]
# ### Test search engine

# %% [markdown]
# Create Faiss index

# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.7.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 32.6 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.7.4

# %%
import faiss
import numpy as np

file_path = "/content/drive/MyDrive/shopee/"
image_features_path = "image_features/image_features.npz"

image_features = np.load(f"{file_path}{image_features_path}", allow_pickle=True)

# %%
image_features['image_features'].shape
# Out:
# (100000, 1000)

# %%
dimension = 1000

index_faiss = faiss.IndexFlatL2(dimension)

# Add the image_features to the Faiss index
index_faiss.add(image_features["image_features"])

# %% [markdown]
# Update file test.jpg sample

# %%
from PIL import Image
import matplotlib.pyplot as plt

image = Image.open("test.jpg")

image_query = np.array(image, dtype=np.float32) / 255.0

print(image_query.shape)

plt.figure(figsize=(4,4))
plt.imshow(image_query)
# Out:
# (320, 320, 3)

# %% [markdown]
# Inference

# %%
import torch
import torchvision.models as models

# Load the pre-trained model
efficientnet_b3 = models.efficientnet_b3(weights='IMAGENET1K_V1')

# Set the model to evaluation mode
efficientnet_b3.eval()

# Use a GPU (if available) for inference
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
efficientnet_b3 = efficientnet_b3.to(device)

image_query = image_query[np.newaxis,...]
image_query = image_query.transpose((0, 3, 1, 2))
print(image_query.shape)

# Convert to a PyTorch tensor
image_query = torch.tensor(image_query, dtype=torch.float32)
image_query = image_query.to(device)


# Forward pass through the model
with torch.no_grad():
    output = efficientnet_b3(image_query)

# print("output", output)
print("output", output.shape)
# Out:
# (1, 3, 320, 320)
# output torch.Size([1, 1000])

# %%
# Convert to numpy array
query_vector = output.detach().cpu().numpy()
print("query_vector", query_vector.shape)
# Out:
# query_vector (1, 1000)

# %% [markdown]
# Search

# %%
k = 10
distances, indices = index_faiss.search(query_vector, k)

# Results
print("\nDistances to nearest neighbors:")
print(distances[0])

print("\nNearest neighbors:")
print("indices", indices)
# Out:
# Distances to nearest neighbors:
# [1.0636925e-09 1.9026660e+02 1.9474541e+02 2.0266315e+02 2.1175455e+02
#  2.1584424e+02 2.2993147e+02 2.3084512e+02 2.4190027e+02 2.4503253e+02]
#
# Nearest neighbors:
# indices [[38486 38574 38552 38628 38614 38627 38625 19600 38519 38547]]

# %%
# Read the CSV file into a pandas DataFrame
import pandas as pd

df = pd.read_csv(file_path + "data.csv")

item_image = df["item_image"]
item_name = df["item_name"]

# %%
for index in indices[0]:
    print(index)
    print("item_name", item_name[index])
    print("item_url", item_image[index])
    print()
# Out:
# 38486
# item_name Áo Khoác Bomber Nam 5S, Cản Gió, Chống Bám Bụi, Thiết Kế Basic Trẻ Trung, Lịch Lãm (AKB22001)
# item_url https://down-vn.img.susercontent.com/file/sg-11134201-22120-wuwhiuqdnykv7e_tn
#
# 38574
# item_name Áo Khoác Bomber Nam 5S, Công Nghệ Trượt Nước, Cản Gió, Thiết Kế Basic, Năng Động (03-AKB22001)
# item_url https://down-vn.img.susercontent.com/file/sg-11134201-22120-6u9ivqtewwkv99_tn
#
# 38552
# item_name Áo Khoác Bomber Nam 5S LÓT NỈ, Chống Bụi, Trượt Nước, Cực Ấm, Thiết Kế Trẻ Trung (AKB22003)
# item_url https://down-vn.img.susercontent.com/file/sg-11134201-22120-4js51b4ccvkv70_tn
#
# 38628
# item_name Áo Khoác Thể Thao Nam DELICATE 5S (5 Màu), Chất Poly Cao Cấp, Trượt Nước, Cản Gió, Thiết Kế Khỏe Khoắn (01-AKG22009)
# item_url https://down-vn.img.susercontent.com/file/sg-11134201-22100-5joxom5angivc1_tn
#
# 38614
# item_name Áo Bomber Nam 5S (5 màu) Premium, Công Nghệ BLOCKTECH, Trượt Nước, Cản Gió, Thiết Kế Basic, Năng Động (01-AKB22001)
# item_url https://down-vn.img.susercontent.com/file/sg-11134201-22120-aylmuhxpwwkv08_tn
#
# 38627
# item_name Áo Nỉ Nam Trơn Thêu Logo 5S (6 màu), Chất Cotton Mềm Mại, Giữ Ấm, Phong Cách Hiện Đại (ANO22047)
# item_url https://down-vn.img.susercontent.com/file/sg-11134201-22120-mtfev24x2xkv34_tn
#
# 38625
# item_name Áo Sweater Nỉ Nam 5S, Thiết Kế Trơn Basic, Chất Liệu Cao Cấp, Dày Dặn, Dễ Chịu (03-ANO22047)
# item_url https://down-vn.img.susercontent.com/file/sg-11134201-22120-zlkdhwpzotkv4d_tn
#
# 19600
# item_name Áo khoác dù 2 lớp sọc tay thêu logo cao cấp LADOS-2050 co giãn, thoải mái, chống nước, form đẹp
# item_url https://down-vn.img.susercontent.com/file/88d59faf7610d1d10b8a3870ab607625_tn
#
# 38519
# item_name Áo Giữ Nhiệt Nam 5S Cao Cấp, Siêu Mịn, Mềm, Công Nghệ HEATTECH Siêu Ấm, Thiết Kế, Màu Sắc Basic Dễ Mặc (AGO22001)
# item_url https://down-vn.img.susercontent.com/file/sg-11134201-23010-4kqdbu5nsemv3e_tn
#
# 38547
# item_name Bộ Quần Áo Nỉ Nam 5S (5 màu), Vải Cotton USA Cao Cấp, Mềm Mại, Không Bai Xù, Co Giãn Thoải Mái (02-BNI22036)
# item_url https://down-vn.img.susercontent.com/file/sg-11134201-22110-du6ra0clmgkvfe_tn

# %%
import requests

def url_to_numpy(url):
    # Fetch the image from the URL
    response = requests.get(url, stream=True)

    # Open the image using PIL
    image = Image.open(response.raw)

    # Convert the image to a NumPy array
    img_array = np.array(image, dtype=np.uint8)

    return img_array

for i, index in enumerate(indices[0]):
    url = item_image[index]
    img_array = url_to_numpy(url)
    plt.subplot(3, 4, i+1)
    plt.title(f"Top {i+1}")
    plt.axis('off')
    plt.imshow(img_array)
plt.show()
